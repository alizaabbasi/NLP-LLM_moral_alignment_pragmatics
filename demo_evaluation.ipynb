# %%
import sys
import os
import pandas as pd

# Check where the notebook thinks it is running from
current_dir = os.path.abspath(os.path.join('.'))

# If the notebook is trapped inside 'src', move up to the root folder
if current_dir.endswith('src'):
    root_dir = os.path.abspath(os.path.join('..'))
else:
    root_dir = current_dir

# Add the correct root folder to Python's search path
if root_dir not in sys.path:
    sys.path.append(root_dir)

from src.analyzer import Analyzer
from src.visualizer import Visualizer

# Load the experiment results using the absolute root path
csv_path = os.path.join(root_dir, 'results', 'experiment_results.csv')
df = pd.read_csv(csv_path)

# Convert the DataFrame back to a list of dictionaries for our analyzer module
saved_results = df.to_dict(orient='records')
print(f"Successfully loaded {len(saved_results)} experiment records from your CSV!")

# %%
# Initialize your custom analyzer class
analyzer = Analyzer()
metrics = analyzer.analyze_batch(saved_results)

# 1. Plot the Pie Chart
Visualizer.plot_compliance(metrics)

# 2. Plot the Histogram
Visualizer.plot_response_lengths(saved_results)
